# %% [markdown]
# <a href="https://colab.research.google.com/github/DrFaus/Estadistica2025B/blob/main/gym_members_exercise_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/DrFaus/Estadistica2025B/refs/heads/main/gym_members_exercise_tracking.csv"

df = pd.read_csv(url)

df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                        1.69           1313.0         Yoga            12.6
# 1                        1.30            883.0         HIIT            33.9
# 2                        1.11            677.0       Cardio            33.4
# 3                        0.59            532.0     Strength            28.8
# 4                        0.64            556.0     Strength            29.2
# ..                        ...              ...          ...             ...
# 968                      1.57           1364.0     Strength            10.0
# 969                      1.38           1260.0     Strength            25.0
# 970                      1.72            929.0       Cardio            18.8
# 971                      1.10            883.0         HIIT            28.2
# 972                      0.75            542.0     Strength            28.8
#
#      Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                      3.5                              4                 3
# 1                      2.1                              4                 2
# 2                      2.3                              4                 2
# 3                      2.1                              3                 1
# 4                      2.8                              3                 1
# ..                     ...                            ...               ...
# 968                    3.5                              4                 3
# 969                    3.0                              2                 1
# 970                    2.7                              5                 3
# 971                    2.1                              3                 2
# 972                    3.5                              2                 1
#
#        BMI
# 0    30.20
# 1    32.00
# 2    24.71
# 3    18.41
# 4    14.39
# ..     ...
# 968  28.77
# 969  25.69
# 970  19.50
# 971  37.74
# 972  33.38
#
# [973 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
df.columns = ['edad', 'genero', 'peso', 'altura', 'maximo_BPM', 'promedio_BPM',
       'descanso_BPM', 'duracion', 'calorias_quemadas',
       'tipo_ejercicio', 'porcentaje_grasa', 'agua_tomada',
       'frecuencia_ejercicio', 'nivel_experiencia', 'BMI']

df
# Out:
#      edad  genero   peso  altura  maximo_BPM  promedio_BPM  descanso_BPM  \
# 0      56    Male   88.3    1.71         180           157            60
# 1      46  Female   74.9    1.53         179           151            66
# 2      32  Female   68.1    1.66         167           122            54
# 3      25    Male   53.2    1.70         190           164            56
# 4      38    Male   46.1    1.79         188           158            68
# ..    ...     ...    ...     ...         ...           ...           ...
# 968    24    Male   87.1    1.74         187           158            67
# 969    25    Male   66.6    1.61         184           166            56
# 970    59  Female   60.4    1.76         194           120            53
# 971    32    Male  126.4    1.83         198           146            62
# 972    46    Male   88.7    1.63         166           146            66
#
#      duracion  calorias_quemadas tipo_ejercicio  porcentaje_grasa  \
# 0        1.69             1313.0           Yoga              12.6
# 1        1.30              883.0           HIIT              33.9
# 2        1.11              677.0         Cardio              33.4
# 3        0.59              532.0       Strength              28.8
# 4        0.64              556.0       Strength              29.2
# ..        ...                ...            ...               ...
# 968      1.57             1364.0       Strength              10.0
# 969      1.38             1260.0       Strength              25.0
# 970      1.72              929.0         Cardio              18.8
# 971      1.10              883.0           HIIT              28.2
# 972      0.75              542.0       Strength              28.8
#
#      agua_tomada  frecuencia_ejercicio  nivel_experiencia    BMI
# 0            3.5                     4                  3  30.20
# 1            2.1                     4                  2  32.00
# 2            2.3                     4                  2  24.71
# 3            2.1                     3                  1  18.41
# 4            2.8                     3                  1  14.39
# ..           ...                   ...                ...    ...
# 968          3.5                     4                  3  28.77
# 969          3.0                     2                  1  25.69
# 970          2.7                     5                  3  19.50
# 971          2.1                     3                  2  37.74
# 972          3.5                     2                  1  33.38
#
# [973 rows x 15 columns]

# %%
df = df.dropna()
df
# Out:
#      edad  genero   peso  altura  maximo_BPM  promedio_BPM  descanso_BPM  \
# 0      56    Male   88.3    1.71         180           157            60
# 1      46  Female   74.9    1.53         179           151            66
# 2      32  Female   68.1    1.66         167           122            54
# 3      25    Male   53.2    1.70         190           164            56
# 4      38    Male   46.1    1.79         188           158            68
# ..    ...     ...    ...     ...         ...           ...           ...
# 968    24    Male   87.1    1.74         187           158            67
# 969    25    Male   66.6    1.61         184           166            56
# 970    59  Female   60.4    1.76         194           120            53
# 971    32    Male  126.4    1.83         198           146            62
# 972    46    Male   88.7    1.63         166           146            66
#
#      duracion  calorias_quemadas tipo_ejercicio  porcentaje_grasa  \
# 0        1.69             1313.0           Yoga              12.6
# 1        1.30              883.0           HIIT              33.9
# 2        1.11              677.0         Cardio              33.4
# 3        0.59              532.0       Strength              28.8
# 4        0.64              556.0       Strength              29.2
# ..        ...                ...            ...               ...
# 968      1.57             1364.0       Strength              10.0
# 969      1.38             1260.0       Strength              25.0
# 970      1.72              929.0         Cardio              18.8
# 971      1.10              883.0           HIIT              28.2
# 972      0.75              542.0       Strength              28.8
#
#      agua_tomada  frecuencia_ejercicio  nivel_experiencia    BMI
# 0            3.5                     4                  3  30.20
# 1            2.1                     4                  2  32.00
# 2            2.3                     4                  2  24.71
# 3            2.1                     3                  1  18.41
# 4            2.8                     3                  1  14.39
# ..           ...                   ...                ...    ...
# 968          3.5                     4                  3  28.77
# 969          3.0                     2                  1  25.69
# 970          2.7                     5                  3  19.50
# 971          2.1                     3                  2  37.74
# 972          3.5                     2                  1  33.38
#
# [973 rows x 15 columns]

# %%
df["genero"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Prueba de hipótesis

print("H₀: σ₁² = σ₂² (varianzas iguales)")
print("H₁: σ₁² ≠ σ₂² (varianzas diferentes)")
print("α: 0.05")

from scipy.stats import f

# Dos muestras
grupo_a = df[df["genero"] == "Male"]["calorias_quemadas"]
grupo_b = df[df["genero"] == "Female"]["calorias_quemadas"]

# Tamaños
n_a = len(grupo_a)
n_b = len(grupo_b)

# Varianzas muestrales
s2_a = grupo_a.var()
s2_b = grupo_b.var()

# Estadístico F
F = s2_a / s2_b

# Grados de libertad
v_a = n_a - 1
v_b = n_b - 1

# Valor-p
# valor_p = f.cdf(F, v_a, v_b) # cola izquierda
# valor_p = f.sf(F, v_a, v_b) # cola derecha
valor_p = 2 * min(f.cdf(F, v_a, v_b), f.sf(F, v_a, v_b))

print(f"F = {F:.4f}")
print(f"valor-p = {valor_p:.4f}")
# Out:
# H₀: σ₁² = σ₂² (varianzas iguales)
# H₁: σ₁² ≠ σ₂² (varianzas diferentes)
# α: 0.05
# F = 1.3182
# valor-p = 0.0025

# %%
# Prueba de hipótesis

print("H₀: μ₁ - μ₂ = 0")
print("H₁: μ₁ - μ₂ > 0")
print("α: 0.01")

from scipy.stats import ttest_ind

# Prueba t con varianzas iguales (homocedasticidad)
# equal_var = True significa que hay homoscedasticidad (varianzas iguales)
# equal_var = False significa que hay heteroscedasticidad (varianzas desiguales)

# estadistico_t, valor_p = ttest_ind(grupo1, grupo2, equal_var=False, alternative = 'less') # cola izquierda
# estadistico_t, valor_p = ttest_ind(grupo_a, grupo_b, equal_var=True, alternative = 'greater') # cola derecha
estadistico_t, valor_p = ttest_ind(grupo_a, grupo_b, equal_var=True, alternative = 'two-sided') # dos colas

print(f"t = {estadistico_t:.4f}")
print(f"valor-p = {valor_p:.4f}")
# Out:
# H₀: μ₁ - μ₂ = 0
# H₁: μ₁ - μ₂ > 0
# α: 0.01
# t = 4.7485
# valor-p = 0.0000

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols('calorias_quemadas ~ C(genero)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#               df        sum_sq       mean_sq          F    PR(>F)
# C(genero)    1.0  1.639714e+06  1.639714e+06  22.547934  0.000002
# Residual   971.0  7.061235e+07  7.272126e+04        NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['calorias_quemadas'], # Variable de respuesta
    groups=df['genero'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Generos", xlabel="Calorias quemadas")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
# Female   Male  82.2071   0.0 48.2331 116.181   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df = df[df["genero"] == "Male"]
df = df.drop(columns = ["genero"])
df
# Out:
#      edad   peso  altura  maximo_BPM  promedio_BPM  descanso_BPM  duracion  \
# 0      56   88.3    1.71         180           157            60      1.69
# 3      25   53.2    1.70         190           164            56      0.59
# 4      38   46.1    1.79         188           158            68      0.64
# 6      36   70.3    1.72         174           169            73      1.49
# 8      28  121.7    1.94         185           127            52      1.03
# ..    ...    ...     ...         ...           ...           ...       ...
# 967    20   55.0    1.60         172           168            67      1.12
# 968    24   87.1    1.74         187           158            67      1.57
# 969    25   66.6    1.61         184           166            56      1.38
# 971    32  126.4    1.83         198           146            62      1.10
# 972    46   88.7    1.63         166           146            66      0.75
#
#      calorias_quemadas tipo_ejercicio  porcentaje_grasa  agua_tomada  \
# 0               1313.0           Yoga              12.6          3.5
# 3                532.0       Strength              28.8          2.1
# 4                556.0       Strength              29.2          2.8
# 6               1385.0         Cardio              21.3          2.3
# 8                719.0       Strength              28.9          2.6
# ..                 ...            ...               ...          ...
# 967             1035.0           Yoga              24.0          3.2
# 968             1364.0       Strength              10.0          3.5
# 969             1260.0       Strength              25.0          3.0
# 971              883.0           HIIT              28.2          2.1
# 972              542.0       Strength              28.8          3.5
#
#      frecuencia_ejercicio  nivel_experiencia    BMI
# 0                       4                  3  30.20
# 3                       3                  1  18.41
# 4                       3                  1  14.39
# 6                       3                  2  23.76
# 8                       4                  2  32.34
# ..                    ...                ...    ...
# 967                     4                  2  21.48
# 968                     4                  3  28.77
# 969                     2                  1  25.69
# 971                     3                  2  37.74
# 972                     2                  1  33.38
#
# [511 rows x 14 columns]

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols('calorias_quemadas ~ C(tipo_ejercicio)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                       df        sum_sq       mean_sq         F   PR(>F)
# C(tipo_ejercicio)    3.0  2.609970e+05  86998.986350  1.059599  0.36586
# Residual           507.0  4.162754e+07  82105.609073       NaN      NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(
    endog=df['calorias_quemadas'], # Variable de respuesta
    groups=df['tipo_ejercicio'],          # Variable categorica
    alpha=nivel_de_significancia) # nivel de significancia

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Tipo de ejercicio", xlabel="Calorias quemadas")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#  group1   group2  meandiff p-adj    lower    upper   reject
# -----------------------------------------------------------
#   Cardio     HIIT  45.1506 0.6107  -49.7903 140.0914  False
#   Cardio Strength  20.9891 0.9336  -69.9472 111.9255  False
#   Cardio     Yoga  -16.288 0.9677 -107.5578  74.9818  False
#     HIIT Strength -24.1614  0.911 -118.1072  69.7844  False
#     HIIT     Yoga -61.4386 0.3354 -155.7073  32.8301  False
# Strength     Yoga -37.2772 0.7111 -127.5115  52.9571  False
# -----------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df = df.drop(columns = ["tipo_ejercicio"])
df
# Out:
#      edad   peso  altura  maximo_BPM  promedio_BPM  descanso_BPM  duracion  \
# 0      56   88.3    1.71         180           157            60      1.69
# 3      25   53.2    1.70         190           164            56      0.59
# 4      38   46.1    1.79         188           158            68      0.64
# 6      36   70.3    1.72         174           169            73      1.49
# 8      28  121.7    1.94         185           127            52      1.03
# ..    ...    ...     ...         ...           ...           ...       ...
# 967    20   55.0    1.60         172           168            67      1.12
# 968    24   87.1    1.74         187           158            67      1.57
# 969    25   66.6    1.61         184           166            56      1.38
# 971    32  126.4    1.83         198           146            62      1.10
# 972    46   88.7    1.63         166           146            66      0.75
#
#      calorias_quemadas  porcentaje_grasa  agua_tomada  frecuencia_ejercicio  \
# 0               1313.0              12.6          3.5                     4
# 3                532.0              28.8          2.1                     3
# 4                556.0              29.2          2.8                     3
# 6               1385.0              21.3          2.3                     3
# 8                719.0              28.9          2.6                     4
# ..                 ...               ...          ...                   ...
# 967             1035.0              24.0          3.2                     4
# 968             1364.0              10.0          3.5                     4
# 969             1260.0              25.0          3.0                     2
# 971              883.0              28.2          2.1                     3
# 972              542.0              28.8          3.5                     2
#
#      nivel_experiencia    BMI
# 0                    3  30.20
# 3                    1  18.41
# 4                    1  14.39
# 6                    2  23.76
# 8                    2  32.34
# ..                 ...    ...
# 967                  2  21.48
# 968                  3  28.77
# 969                  1  25.69
# 971                  2  37.74
# 972                  1  33.38
#
# [511 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(30, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, center=0, cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
x = df["duracion"]
y = df["calorias_quemadas"]

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (16, 8), dpi = 100)
plt.scatter(x, y, label = "Calorias quemadas", color = 'red')
plt.xlabel('Duracion en horas') # nombrar eje x
plt.ylabel('Calorias quemadas') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

# 3. ¿Los datos soportan la suposición de linealidad?
# Sí

# 4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)

plt.plot(x, yc, color = 'black', linestyle = '--')

# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')

# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'blue')
plt.xlabel('Duracion en horas')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')

# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')

# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
print(f'para x = 70, y = {modelo.predict([1, 70])}')
print(f'para x = 75, y = {modelo.predict([1, 75])}')
print(f'para x = 84, y = {modelo.predict([1, 84])}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('calorias_quemadas ~ duracion', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de correlación:  0.9255
#
# Coeficiente de determinación:  0.8566
#
# Intervalo de confianza para b1 de  95%
#  742.9723 < b1 <  797.8646
#
# valor-p de Shapiro:  0.2869
#
# valor_p de Breusch-Pagan:  0.0000
#
# para x = 70, y = [53908.84199448]
# para x = 75, y = [57760.93440256]
# para x = 84, y = [64694.70073711]
#              df        sum_sq       mean_sq            F         PR(>F)
# duracion    1.0  3.588300e+07  3.588300e+07  3041.268097  7.944049e-217
# Residual  509.0  6.005537e+06  1.179870e+04          NaN            NaN
